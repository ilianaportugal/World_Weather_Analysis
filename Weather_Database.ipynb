# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 719

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cd253319dd7f58f7aa42ceea2dbb3feb

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description, 
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | barrow
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | pisco
# Processing Record 5 of Set 1 | kavaratti
# Processing Record 6 of Set 1 | dodge city
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | sola
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | sao filipe
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | aklavik
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | kavieng
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 1 | chanute
# Processing Record 28 of Set 1 | carutapera
# Processing Record 29 of Set 1 | les cayes
# Processing Record 30 of Set 1 | quijingue
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | imbituba
# Processing Record 35 of Set 1 | vestnes
# Processing Record 36 of Set 1 | constantine
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | lampazos de naranjo
# Processing Record 39 of Set 1 | cidreira
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 1 | cabo san lucas
# Processing Record 44 of Set 1 | seoul
# Processing Record 45 of Set 1 | asfi
# Processing Record 46 of Set 1 | wahiawa
# Processing Record 47 of Set 1 | port blair
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | adrar
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | banjar
# Processing Record 4 of Set 2 | nuuk
# Processing Record 5 of Set 2 | luanda
# Processing Record 6 of Set 2 | praia da vitoria
# Processing Record 7 of Set 2 | baruun-urt
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | korla
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | nouadhibou
# Processing Record 14 of Set 2 | sakakah
# Processing Record 15 of Set 2 | namatanai
# Processing Record 16 of Set 2 | bestobe
# Processing Record 17 of Set 2 | comodoro rivadavia
# Processing Record 18 of Set 2 | coihaique
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | gachantiva
# City not found. Skipping...
# Processing Record 26 of Set 2 | rorvik
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | padang
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | olinda
# Processing Record 35 of Set 2 | imeni poliny osipenko
# Processing Record 36 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 2 | pemangkat
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | camacha
# Processing Record 40 of Set 2 | butaritari
# Processing Record 41 of Set 2 | belmonte
# Processing Record 42 of Set 2 | nizip
# Processing Record 43 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 2 | collie
# Processing Record 45 of Set 2 | kagoro
# Processing Record 46 of Set 2 | atbasar
# Processing Record 47 of Set 2 | sungurlu
# Processing Record 48 of Set 2 | scarborough
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | tyukhtet
# Processing Record 1 of Set 3 | krasnoarmeysk
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | uaua
# Processing Record 5 of Set 3 | tezu
# Processing Record 6 of Set 3 | chaa-khol
# City not found. Skipping...
# Processing Record 7 of Set 3 | san pedro
# Processing Record 8 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 3 | el alto
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | ancud
# Processing Record 12 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 3 | bambous virieux
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | acapulco
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | krasnyy chikoy
# Processing Record 18 of Set 3 | rawson
# Processing Record 19 of Set 3 | ueckermunde
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | clearfield
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | hollola
# Processing Record 25 of Set 3 | iqaluit
# Processing Record 26 of Set 3 | azle
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | hamilton
# Processing Record 29 of Set 3 | kiunga
# Processing Record 30 of Set 3 | torquay
# Processing Record 31 of Set 3 | shenjiamen
# Processing Record 32 of Set 3 | manohar thana
# Processing Record 33 of Set 3 | lebu
# Processing Record 34 of Set 3 | bac lieu
# Processing Record 35 of Set 3 | felanitx
# Processing Record 36 of Set 3 | beloha
# Processing Record 37 of Set 3 | hasaki
# Processing Record 38 of Set 3 | kaoma
# Processing Record 39 of Set 3 | khartoum
# Processing Record 40 of Set 3 | broken hill
# Processing Record 41 of Set 3 | sorland
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | flin flon
# Processing Record 44 of Set 3 | laiyang
# Processing Record 45 of Set 3 | nunoa
# Processing Record 46 of Set 3 | mayumba
# Processing Record 47 of Set 3 | biltine
# Processing Record 48 of Set 3 | pedernales
# Processing Record 49 of Set 3 | codrington
# Processing Record 50 of Set 3 | mount gambier
# Processing Record 1 of Set 4 | katangli
# Processing Record 2 of Set 4 | tornio
# Processing Record 3 of Set 4 | sardulgarh
# Processing Record 4 of Set 4 | olga
# Processing Record 5 of Set 4 | siguiri
# Processing Record 6 of Set 4 | mopipi
# Processing Record 7 of Set 4 | cavalcante
# Processing Record 8 of Set 4 | naryan-mar
# Processing Record 9 of Set 4 | halifax
# Processing Record 10 of Set 4 | puerto ayora
# Processing Record 11 of Set 4 | gharb
# City not found. Skipping...
# Processing Record 12 of Set 4 | chochola
# Processing Record 13 of Set 4 | archidona
# Processing Record 14 of Set 4 | vanavara
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | makokou
# Processing Record 17 of Set 4 | ko samui
# Processing Record 18 of Set 4 | batagay-alyta
# Processing Record 19 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 4 | norman wells
# Processing Record 21 of Set 4 | manjacaze
# Processing Record 22 of Set 4 | floresti
# Processing Record 23 of Set 4 | okha
# Processing Record 24 of Set 4 | vredendal
# Processing Record 25 of Set 4 | lorengau
# Processing Record 26 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 4 | kloulklubed
# Processing Record 28 of Set 4 | olds
# Processing Record 29 of Set 4 | kiama
# Processing Record 30 of Set 4 | lazaro cardenas
# Processing Record 31 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 4 | dublin
# Processing Record 33 of Set 4 | leningradskiy
# Processing Record 34 of Set 4 | gravenhurst
# Processing Record 35 of Set 4 | talara
# Processing Record 36 of Set 4 | scottsburgh
# City not found. Skipping...
# Processing Record 37 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | hauge
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | nikolskoye
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | shelburne
# Processing Record 44 of Set 4 | jos
# Processing Record 45 of Set 4 | tuktoyaktuk
# Processing Record 46 of Set 4 | milledgeville
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 4 | nata
# Processing Record 1 of Set 5 | ulaangom
# Processing Record 2 of Set 5 | cassilandia
# Processing Record 3 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 4 of Set 5 | nara
# Processing Record 5 of Set 5 | zaysan
# Processing Record 6 of Set 5 | tuatapere
# Processing Record 7 of Set 5 | lasa
# Processing Record 8 of Set 5 | egvekinot
# Processing Record 9 of Set 5 | dunedin
# Processing Record 10 of Set 5 | hauterive
# Processing Record 11 of Set 5 | saint-joseph
# Processing Record 12 of Set 5 | yumen
# Processing Record 13 of Set 5 | chumikan
# Processing Record 14 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | ranot
# Processing Record 17 of Set 5 | faanui
# Processing Record 18 of Set 5 | dikson
# Processing Record 19 of Set 5 | saint anthony
# Processing Record 20 of Set 5 | guerrero negro
# Processing Record 21 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 5 | srandakan
# Processing Record 23 of Set 5 | vangaindrano
# Processing Record 24 of Set 5 | huarmey
# Processing Record 25 of Set 5 | severo-yeniseyskiy
# Processing Record 26 of Set 5 | deputatskiy
# Processing Record 27 of Set 5 | chabahar
# Processing Record 28 of Set 5 | valkeala
# Processing Record 29 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 5 | callaguip
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | bonavista
# Processing Record 34 of Set 5 | zhigansk
# Processing Record 35 of Set 5 | hirara
# Processing Record 36 of Set 5 | prestea
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | mount isa
# Processing Record 39 of Set 5 | rio gallegos
# Processing Record 40 of Set 5 | shimoda
# Processing Record 41 of Set 5 | ambilobe
# Processing Record 42 of Set 5 | cabra
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | tazovskiy
# Processing Record 45 of Set 5 | evensk
# Processing Record 46 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 5 | champerico
# Processing Record 48 of Set 5 | verkhniy avzyan
# Processing Record 49 of Set 5 | dondo
# Processing Record 50 of Set 5 | phalodi
# Processing Record 1 of Set 6 | gorgan
# Processing Record 2 of Set 6 | okhotsk
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 6 | la gomera
# Processing Record 6 of Set 6 | maroantsetra
# Processing Record 7 of Set 6 | nisia floresta
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | miracema do tocantins
# Processing Record 10 of Set 6 | portalegre
# Processing Record 11 of Set 6 | orapa
# Processing Record 12 of Set 6 | kutum
# Processing Record 13 of Set 6 | laguna
# Processing Record 14 of Set 6 | marakkanam
# Processing Record 15 of Set 6 | bathsheba
# Processing Record 16 of Set 6 | springfield
# Processing Record 17 of Set 6 | ostrovnoy
# Processing Record 18 of Set 6 | gwanda
# Processing Record 19 of Set 6 | husavik
# Processing Record 20 of Set 6 | tenenkou
# Processing Record 21 of Set 6 | mahebourg
# Processing Record 22 of Set 6 | tarakan
# Processing Record 23 of Set 6 | henties bay
# Processing Record 24 of Set 6 | talcahuano
# Processing Record 25 of Set 6 | bucerias
# Processing Record 26 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 27 of Set 6 | nguruka
# Processing Record 28 of Set 6 | saint george
# Processing Record 29 of Set 6 | grindavik
# Processing Record 30 of Set 6 | boa viagem
# Processing Record 31 of Set 6 | carnarvon
# Processing Record 32 of Set 6 | trairi
# Processing Record 33 of Set 6 | mahajanga
# Processing Record 34 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 35 of Set 6 | yuncheng
# Processing Record 36 of Set 6 | tukrah
# Processing Record 37 of Set 6 | prince rupert
# Processing Record 38 of Set 6 | ixtapa
# Processing Record 39 of Set 6 | rio grande
# Processing Record 40 of Set 6 | tilichiki
# Processing Record 41 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 6 | isangel
# Processing Record 43 of Set 6 | wuwei
# Processing Record 44 of Set 6 | meulaboh
# Processing Record 45 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 6 | muscle shoals
# Processing Record 47 of Set 6 | shaowu
# Processing Record 48 of Set 6 | piranshahr
# Processing Record 49 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 6 | kollam
# Processing Record 1 of Set 7 | kilindoni
# Processing Record 2 of Set 7 | san andres
# Processing Record 3 of Set 7 | qaanaaq
# Processing Record 4 of Set 7 | warmbad
# Processing Record 5 of Set 7 | mormugao
# Processing Record 6 of Set 7 | caruray
# Processing Record 7 of Set 7 | klaksvik
# Processing Record 8 of Set 7 | vestmanna
# Processing Record 9 of Set 7 | inhambane
# Processing Record 10 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | abu dhabi
# Processing Record 13 of Set 7 | tessaoua
# Processing Record 14 of Set 7 | sioux lookout
# Processing Record 15 of Set 7 | severodvinsk
# Processing Record 16 of Set 7 | aitape
# Processing Record 17 of Set 7 | mehamn
# Processing Record 18 of Set 7 | eenhana
# Processing Record 19 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 7 | tiznit
# Processing Record 21 of Set 7 | sinnamary
# Processing Record 22 of Set 7 | gorom-gorom
# Processing Record 23 of Set 7 | tomatlan
# Processing Record 24 of Set 7 | rocha
# Processing Record 25 of Set 7 | taoudenni
# Processing Record 26 of Set 7 | weihe
# Processing Record 27 of Set 7 | berlevag
# Processing Record 28 of Set 7 | icod de los vinos
# Processing Record 29 of Set 7 | naushki
# Processing Record 30 of Set 7 | surt
# Processing Record 31 of Set 7 | castlegar
# Processing Record 32 of Set 7 | gambela
# Processing Record 33 of Set 7 | guiratinga
# Processing Record 34 of Set 7 | gizo
# Processing Record 35 of Set 7 | pokhara
# Processing Record 36 of Set 7 | vila franca do campo
# Processing Record 37 of Set 7 | oktyabrskoye
# Processing Record 38 of Set 7 | lively
# Processing Record 39 of Set 7 | bhag
# Processing Record 40 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 7 | pangnirtung
# Processing Record 42 of Set 7 | avera
# Processing Record 43 of Set 7 | namwala
# Processing Record 44 of Set 7 | esna
# Processing Record 45 of Set 7 | atar
# Processing Record 46 of Set 7 | mandeville
# Processing Record 47 of Set 7 | los llanos de aridane
# Processing Record 48 of Set 7 | kulhudhuffushi
# Processing Record 49 of Set 7 | urucara
# Processing Record 50 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 8 | kalamaria
# Processing Record 2 of Set 8 | oksbol
# Processing Record 3 of Set 8 | mustasaari
# Processing Record 4 of Set 8 | garavuti
# Processing Record 5 of Set 8 | auki
# Processing Record 6 of Set 8 | chalus
# Processing Record 7 of Set 8 | anchorage
# Processing Record 8 of Set 8 | rosetta
# Processing Record 9 of Set 8 | otjimbingwe
# Processing Record 10 of Set 8 | olafsvik
# Processing Record 11 of Set 8 | torbay
# Processing Record 12 of Set 8 | port hardy
# Processing Record 13 of Set 8 | lugoj
# Processing Record 14 of Set 8 | ningan
# City not found. Skipping...
# Processing Record 15 of Set 8 | general pico
# Processing Record 16 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 8 | barabai
# Processing Record 18 of Set 8 | biak
# Processing Record 19 of Set 8 | zlobin
# Processing Record 20 of Set 8 | parker
# Processing Record 21 of Set 8 | gladstone
# Processing Record 22 of Set 8 | visby
# Processing Record 23 of Set 8 | xichang
# Processing Record 24 of Set 8 | ust-kan
# Processing Record 25 of Set 8 | almaznyy
# Processing Record 26 of Set 8 | kaitangata
# Processing Record 27 of Set 8 | alyangula
# Processing Record 28 of Set 8 | ust-nera
# Processing Record 29 of Set 8 | kidal
# Processing Record 30 of Set 8 | henzada
# City not found. Skipping...
# Processing Record 31 of Set 8 | teguldet
# Processing Record 32 of Set 8 | sayyan
# Processing Record 33 of Set 8 | yaring
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | port hedland
# Processing Record 36 of Set 8 | cascais
# Processing Record 37 of Set 8 | viransehir
# Processing Record 38 of Set 8 | puro
# Processing Record 39 of Set 8 | dukat
# Processing Record 40 of Set 8 | weiser
# Processing Record 41 of Set 8 | kalemie
# Processing Record 42 of Set 8 | krasnoborsk
# Processing Record 43 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 8 | poyarkovo
# Processing Record 45 of Set 8 | acara
# Processing Record 46 of Set 8 | remedios
# Processing Record 47 of Set 8 | kedrovyy
# Processing Record 48 of Set 8 | kozhva
# Processing Record 49 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 50 of Set 8 | yerbogachen
# Processing Record 1 of Set 9 | solnechnyy
# Processing Record 2 of Set 9 | troitskoye
# Processing Record 3 of Set 9 | yenagoa
# Processing Record 4 of Set 9 | chauk
# Processing Record 5 of Set 9 | sao raimundo nonato
# Processing Record 6 of Set 9 | uniontown
# Processing Record 7 of Set 9 | derzhavinsk
# Processing Record 8 of Set 9 | mabaruma
# Processing Record 9 of Set 9 | bandarbeyla
# Processing Record 10 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 9 | vao
# Processing Record 12 of Set 9 | bangassou
# Processing Record 13 of Set 9 | keshan
# City not found. Skipping...
# Processing Record 14 of Set 9 | eucaliptus
# Processing Record 15 of Set 9 | makakilo city
# Processing Record 16 of Set 9 | flinders
# Processing Record 17 of Set 9 | machakos
# Processing Record 18 of Set 9 | pascagoula
# Processing Record 19 of Set 9 | datong
# Processing Record 20 of Set 9 | lucea
# Processing Record 21 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 9 | chisinau
# Processing Record 23 of Set 9 | kut chap
# Processing Record 24 of Set 9 | haines junction
# Processing Record 25 of Set 9 | airai
# Processing Record 26 of Set 9 | san quintin
# Processing Record 27 of Set 9 | raga
# Processing Record 28 of Set 9 | chernyshevsk
# Processing Record 29 of Set 9 | kahului
# Processing Record 30 of Set 9 | mugla
# Processing Record 31 of Set 9 | palu
# Processing Record 32 of Set 9 | dingle
# Processing Record 33 of Set 9 | karachi
# Processing Record 34 of Set 9 | sojat
# Processing Record 35 of Set 9 | kasane
# Processing Record 36 of Set 9 | zolotukhino
# Processing Record 37 of Set 9 | kota kinabalu
# Processing Record 38 of Set 9 | neyshabur
# Processing Record 39 of Set 9 | bambanglipuro
# Processing Record 40 of Set 9 | alofi
# Processing Record 41 of Set 9 | tessalit
# Processing Record 42 of Set 9 | marzuq
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 9 | pecos
# Processing Record 46 of Set 9 | havre-saint-pierre
# Processing Record 47 of Set 9 | hualmay
# Processing Record 48 of Set 9 | quatre cocos
# Processing Record 49 of Set 9 | misratah
# Processing Record 50 of Set 9 | dasoguz
# Processing Record 1 of Set 10 | seymchan
# Processing Record 2 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 10 | krasnoye
# Processing Record 4 of Set 10 | riyadh
# Processing Record 5 of Set 10 | luquillo
# Processing Record 6 of Set 10 | polyarnyy
# Processing Record 7 of Set 10 | leh
# Processing Record 8 of Set 10 | portsmouth
# Processing Record 9 of Set 10 | ahipara
# Processing Record 10 of Set 10 | buraydah
# Processing Record 11 of Set 10 | monrovia
# Processing Record 12 of Set 10 | fairbanks
# Processing Record 13 of Set 10 | peniche
# Processing Record 14 of Set 10 | cuenca
# Processing Record 15 of Set 10 | wajir
# Processing Record 16 of Set 10 | maykor
# Processing Record 17 of Set 10 | sampit
# Processing Record 18 of Set 10 | lavrentiya
# Processing Record 19 of Set 10 | ginda
# Processing Record 20 of Set 10 | aripuana
# Processing Record 21 of Set 10 | porto novo
# Processing Record 22 of Set 10 | campos
# Processing Record 23 of Set 10 | waingapu
# Processing Record 24 of Set 10 | gobabis
# Processing Record 25 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 26 of Set 10 | progreso
# Processing Record 27 of Set 10 | portland
# Processing Record 28 of Set 10 | krasnoselkup
# Processing Record 29 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 30 of Set 10 | ilulissat
# Processing Record 31 of Set 10 | outlook
# Processing Record 32 of Set 10 | port lincoln
# Processing Record 33 of Set 10 | necochea
# Processing Record 34 of Set 10 | ati
# Processing Record 35 of Set 10 | sribne
# Processing Record 36 of Set 10 | buala
# Processing Record 37 of Set 10 | los algarrobos
# Processing Record 38 of Set 10 | chambas
# Processing Record 39 of Set 10 | itarema
# Processing Record 40 of Set 10 | paysandu
# Processing Record 41 of Set 10 | bengkulu
# Processing Record 42 of Set 10 | campbell river
# Processing Record 43 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 10 | yangjiang
# Processing Record 45 of Set 10 | nizwa
# Processing Record 46 of Set 10 | heishan
# Processing Record 47 of Set 10 | liberty
# Processing Record 48 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 10 | chapais
# Processing Record 50 of Set 10 | aykhal
# Processing Record 1 of Set 11 | antofagasta
# Processing Record 2 of Set 11 | sangar
# Processing Record 3 of Set 11 | miramar
# Processing Record 4 of Set 11 | mattru
# Processing Record 5 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 6 of Set 11 | parrita
# Processing Record 7 of Set 11 | bowen
# Processing Record 8 of Set 11 | cap malheureux
# Processing Record 9 of Set 11 | valentin gomez farias
# Processing Record 10 of Set 11 | salinas
# Processing Record 11 of Set 11 | shingu
# Processing Record 12 of Set 11 | palmer
# Processing Record 13 of Set 11 | atambua
# Processing Record 14 of Set 11 | kualakapuas
# Processing Record 15 of Set 11 | tambun
# Processing Record 16 of Set 11 | san antonio
# Processing Record 17 of Set 11 | rio das ostras
# Processing Record 18 of Set 11 | hirtshals
# Processing Record 19 of Set 11 | mishkino
# Processing Record 20 of Set 11 | yanam
# Processing Record 21 of Set 11 | tlacolula
# Processing Record 22 of Set 11 | kano
# Processing Record 23 of Set 11 | bria
# Processing Record 24 of Set 11 | karasjok
# Processing Record 25 of Set 11 | cabo rojo
# Processing Record 26 of Set 11 | igarka
# Processing Record 27 of Set 11 | margate
# Processing Record 28 of Set 11 | banepa
# Processing Record 29 of Set 11 | ekhabi
# Processing Record 30 of Set 11 | tongzi
# Processing Record 31 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 11 | baherden
# Processing Record 33 of Set 11 | sept-iles
# Processing Record 34 of Set 11 | cabedelo
# Processing Record 35 of Set 11 | mama
# Processing Record 36 of Set 11 | itarantim
# Processing Record 37 of Set 11 | santo antonio de padua
# Processing Record 38 of Set 11 | arawa
# Processing Record 39 of Set 11 | pokaran
# Processing Record 40 of Set 11 | pochutla
# Processing Record 41 of Set 11 | eureka
# Processing Record 42 of Set 11 | opuwo
# Processing Record 43 of Set 11 | keuruu
# Processing Record 44 of Set 11 | fortuna
# Processing Record 45 of Set 11 | harper
# Processing Record 46 of Set 11 | fort wellington
# Processing Record 47 of Set 11 | balykshi
# City not found. Skipping...
# Processing Record 48 of Set 11 | manaus
# Processing Record 49 of Set 11 | valparaiso
# Processing Record 50 of Set 11 | arys
# Processing Record 1 of Set 12 | ucluelet
# Processing Record 2 of Set 12 | svetlaya
# Processing Record 3 of Set 12 | mpika
# Processing Record 4 of Set 12 | bubaque
# Processing Record 5 of Set 12 | ouegoa
# Processing Record 6 of Set 12 | pundaguitan
# Processing Record 7 of Set 12 | komsomolskiy
# Processing Record 8 of Set 12 | vestmannaeyjar
# Processing Record 9 of Set 12 | vincennes
# Processing Record 10 of Set 12 | guhagar
# Processing Record 11 of Set 12 | aban
# Processing Record 12 of Set 12 | bakchar
# Processing Record 13 of Set 12 | muros
# Processing Record 14 of Set 12 | kasempa
# Processing Record 15 of Set 12 | sorong
# Processing Record 16 of Set 12 | shache
# Processing Record 17 of Set 12 | awbari
# Processing Record 18 of Set 12 | tiarei
# Processing Record 19 of Set 12 | tosya
# Processing Record 20 of Set 12 | caraguatatuba
# Processing Record 21 of Set 12 | sangmelima
# Processing Record 22 of Set 12 | salamiyah
# Processing Record 23 of Set 12 | turukhansk
# Processing Record 24 of Set 12 | soyo
# Processing Record 25 of Set 12 | pamanukan
# Processing Record 26 of Set 12 | lagoa
# Processing Record 27 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 28 of Set 12 | mari-turek
# Processing Record 29 of Set 12 | benguela
# Processing Record 30 of Set 12 | mapiri
# Processing Record 31 of Set 12 | katherine
# Processing Record 32 of Set 12 | santa maria
# Processing Record 33 of Set 12 | uspenka
# Processing Record 34 of Set 12 | talaya
# Processing Record 35 of Set 12 | samarai
# Processing Record 36 of Set 12 | urbana
# Processing Record 37 of Set 12 | shiyan
# Processing Record 38 of Set 12 | lisakovsk
# Processing Record 39 of Set 12 | baiyin
# Processing Record 40 of Set 12 | aksarka
# Processing Record 41 of Set 12 | posadas
# Processing Record 42 of Set 12 | kedainiai
# Processing Record 43 of Set 12 | bud
# Processing Record 44 of Set 12 | goderich
# Processing Record 45 of Set 12 | vysokogornyy
# Processing Record 46 of Set 12 | amboasary
# Processing Record 47 of Set 12 | miraflores
# Processing Record 48 of Set 12 | uralets
# Processing Record 49 of Set 12 | nago
# Processing Record 50 of Set 12 | fort nelson
# Processing Record 1 of Set 13 | zalesovo
# Processing Record 2 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 13 | sann
# Processing Record 4 of Set 13 | nantucket
# Processing Record 5 of Set 13 | nemuro
# Processing Record 6 of Set 13 | lewistown
# Processing Record 7 of Set 13 | alta floresta
# Processing Record 8 of Set 13 | byron bay
# Processing Record 9 of Set 13 | mikkeli
# Processing Record 10 of Set 13 | umm lajj
# Processing Record 11 of Set 13 | gubkinskiy
# Processing Record 12 of Set 13 | fare
# Processing Record 13 of Set 13 | gamba
# Processing Record 14 of Set 13 | krasnogorsk
# Processing Record 15 of Set 13 | nome
# Processing Record 16 of Set 13 | mareeba
# Processing Record 17 of Set 13 | kupang
# Processing Record 18 of Set 13 | mackay
# Processing Record 19 of Set 13 | lompoc
# Processing Record 20 of Set 13 | storforshei
# Processing Record 21 of Set 13 | udachnyy
# Processing Record 22 of Set 13 | thinadhoo
# Processing Record 23 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 13 | maun
# Processing Record 25 of Set 13 | bilibino
# Processing Record 26 of Set 13 | kampot
# Processing Record 27 of Set 13 | brae
# Processing Record 28 of Set 13 | never
# Processing Record 29 of Set 13 | matara
# Processing Record 30 of Set 13 | kijang
# Processing Record 31 of Set 13 | port-gentil
# Processing Record 32 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 33 of Set 13 | marsh harbour
# Processing Record 34 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 35 of Set 13 | stelle
# Processing Record 36 of Set 13 | esso
# Processing Record 37 of Set 13 | viedma
# Processing Record 38 of Set 13 | at-bashi
# Processing Record 39 of Set 13 | pandan
# Processing Record 40 of Set 13 | lao cai
# Processing Record 41 of Set 13 | poum
# Processing Record 42 of Set 13 | eyl
# Processing Record 43 of Set 13 | san vicente
# Processing Record 44 of Set 13 | vila velha
# Processing Record 45 of Set 13 | invermere
# Processing Record 46 of Set 13 | ayagoz
# Processing Record 47 of Set 13 | pavilosta
# Processing Record 48 of Set 13 | tecoanapa
# Processing Record 49 of Set 13 | ponnani
# Processing Record 50 of Set 13 | promyshlennaya
# Processing Record 1 of Set 14 | cap-aux-meules
# Processing Record 2 of Set 14 | murray bridge
# Processing Record 3 of Set 14 | gushi
# Processing Record 4 of Set 14 | lefka
# Processing Record 5 of Set 14 | trofors
# Processing Record 6 of Set 14 | grand gaube
# Processing Record 7 of Set 14 | malpe
# Processing Record 8 of Set 14 | mezen
# Processing Record 9 of Set 14 | kuandian
# Processing Record 10 of Set 14 | jilmah
# City not found. Skipping...
# Processing Record 11 of Set 14 | kudat
# Processing Record 12 of Set 14 | presidencia roque saenz pena
# Processing Record 13 of Set 14 | san cristobal
# Processing Record 14 of Set 14 | chernyshevskiy
# Processing Record 15 of Set 14 | monte cristi
# City not found. Skipping...
# Processing Record 16 of Set 14 | ngunguru
# Processing Record 17 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 14 | cockburn town
# Processing Record 19 of Set 14 | bukama
# Processing Record 20 of Set 14 | katsuura
# Processing Record 21 of Set 14 | yulara
# Processing Record 22 of Set 14 | kirakira
# Processing Record 23 of Set 14 | bulgan
# Processing Record 24 of Set 14 | tambo
# Processing Record 25 of Set 14 | swellendam
# Processing Record 26 of Set 14 | filotion
# Processing Record 27 of Set 14 | nuevo casas grandes
# Processing Record 28 of Set 14 | batagay
# Processing Record 29 of Set 14 | pinawa
# Processing Record 30 of Set 14 | calvinia
# Processing Record 31 of Set 14 | santa rosa
# Processing Record 32 of Set 14 | tarauaca
# Processing Record 33 of Set 14 | karratha
# Processing Record 34 of Set 14 | naze
# Processing Record 35 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 14 | burkburnett
# Processing Record 37 of Set 14 | roebourne
# Processing Record 38 of Set 14 | zalantun
# Processing Record 39 of Set 14 | coahuayana
# Processing Record 40 of Set 14 | oistins
# Processing Record 41 of Set 14 | beyneu
# Processing Record 42 of Set 14 | harnosand
# Processing Record 43 of Set 14 | pacific grove
# Processing Record 44 of Set 14 | weligama
# Processing Record 45 of Set 14 | santa isabel do rio negro
# Processing Record 46 of Set 14 | bridlington
# Processing Record 47 of Set 14 | kafar qasem
# City not found. Skipping...
# Processing Record 48 of Set 14 | zhuhai
# Processing Record 49 of Set 14 | high level
# Processing Record 50 of Set 14 | yarada
# Processing Record 1 of Set 15 | alice springs
# Processing Record 2 of Set 15 | kpalime
# Processing Record 3 of Set 15 | north bend
# Processing Record 4 of Set 15 | burnie
# Processing Record 5 of Set 15 | onguday
# Processing Record 6 of Set 15 | krupina
# Processing Record 7 of Set 15 | deder
# Processing Record 8 of Set 15 | kati
# Processing Record 9 of Set 15 | sheridan
# Processing Record 10 of Set 15 | idil
# Processing Record 11 of Set 15 | muncar
# Processing Record 12 of Set 15 | katobu
# Processing Record 13 of Set 15 | kargasok
# Processing Record 14 of Set 15 | shimanovsk
# Processing Record 15 of Set 15 | oussouye
# Processing Record 16 of Set 15 | sobolevo
# Processing Record 17 of Set 15 | apam
# Processing Record 18 of Set 15 | gornyy
# Processing Record 19 of Set 15 | mucurapo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Georgetown   5.41  100.34     91.40        62          20        5.82
# 1          Barrow  71.29 -156.79     39.20        93          90        8.05
# 2        Hermanus -34.42   19.23     54.00        95         100        8.37
# 3           Pisco -13.70  -76.22     61.00        87          90       12.75
# 4       Kavaratti  10.57   72.64     86.00        70          20        9.17
# 5      Dodge City  37.75 -100.02     73.40        56           1       11.41
# 6       Geraldton -28.77  114.60     69.80        49          40        4.70
# 7         Rikitea -23.12 -134.97     71.58        83           9       18.92
# 8          Avarua -21.21 -159.78     71.60        78           9        3.36
# 9  Saint-Philippe -21.36   55.77     77.00        57          37        6.93
#
#   Country       Description                 Date
# 0      MY        few clouds  2020-08-24 06:19:08
# 1      US              mist  2020-08-24 06:19:08
# 2      ZA   overcast clouds  2020-08-24 06:19:08
# 3      PE   overcast clouds  2020-08-24 06:19:08
# 4      IN        few clouds  2020-08-24 06:19:09
# 5      US         clear sky  2020-08-24 06:18:16
# 6      AU  scattered clouds  2020-08-24 06:16:26
# 7      PF        light rain  2020-08-24 06:19:10
# 8      CK         clear sky  2020-08-24 06:16:07
# 9      RE  scattered clouds  2020-08-24 06:19:10

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
